# %%
import os
files = os.listdir('abcd')
import matplotlib.pyplot as plt
import numpy as np

files = [os.path.join('abcd', file_i)
 for file_i in os.listdir('abcd')
 if '.jpg' in file_i]

imgs = [plt.imread(files[file_i])
        for file_i in range(10)]
data = np.array(imgs) 
mean_img = np.quantile(data,1,axis=0) 

plt.imshow(mean_img.astype(np.uint8))
